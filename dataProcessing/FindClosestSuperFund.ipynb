# %% [markdown]
# # Purpose of this program
# 1. Calculate the distances between Sources and Outcomes
# 2. Determine to closest Source to Outcome
# 3. Assign that Source to the closest Outcome.
#
# We will be using Haversine formula to calculate the distance between the Sources and Outcomes.
#
# We will be limiting the search for the closest to those Sources that are in the same City as the Outcomes.
#
# This program will be used on both the Superfund, Cumlivative Risk, and Air Quality data.

# %%
import pandas as pd
# Import the Numpy dependency
import numpy as np
# Import the Haversine formula package.  Calculates distances using lat & log
import haversine as hs
from haversine import Unit

# %% [markdown]
# Bring in Outcome data (500 City) only keeping locational information for now

# %%
# Bringing in 500 city data 
city_file_path = "../ProcessedData/500_City_cleaned.csv"
citydf = pd.read_csv(city_file_path)
citydf.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073003200  0107000-01073003200
# 1        AL  Birmingham     107000  1073003300  0107000-01073003300
# 2        AL  Birmingham     107000  1073010500  0107000-01073010500
# 3        AL  Birmingham     107000  1073010701  0107000-01073010701
# 4        AL  Birmingham     107000  1073010801  0107000-01073010801
#
#    Population2010  Insurance  HighBloodPressure  Cancer  Asthma  HeartDisease  \
# 0           931.0       26.8               57.0     6.0    14.4          11.1
# 1           947.0       21.4               55.2     6.8    12.9           9.7
# 2           114.0       23.9               60.5     7.1    13.6          11.1
# 3            74.0       19.8               24.9     2.7    11.2           2.4
# 4           168.0        7.3               33.0     7.4     8.9           4.5
#
#    AnnualCheckUps  Smokes  MentalHealthIssues   Latitude  Longitude  newFIPS  \
# 0            78.2    29.6                22.0  33.509402 -86.885908     1073
# 1            80.1    22.6                16.7  33.517126 -86.891382     1073
# 2            80.7    26.5                18.6  33.436379 -86.912892     1073
# 3            66.2    18.1                16.1  33.473886 -86.814649     1073
# 4            73.7     8.5                 8.8  33.514098 -86.746697     1073
#
#    CountyFIPS
# 0        1073
# 1        1073
# 2        1073
# 3        1073
# 4        1073

# %%
citydf = citydf[['StateAbbr','PlaceName','PlaceFIPS','TractFIPS','Place_TractID',
                 'CountyFIPS','Latitude','Longitude']]

# %%
citydf['city_state'] = citydf.PlaceName + "_" +  citydf.StateAbbr

# %% [markdown]
# Reading in Source and limiting it to select cities

# %%
# Superfund data
input_file_path2 = "../ProcessedData/Superfund.csv"
sfdf = pd.read_csv(input_file_path2)
sfdf.head()
# Out:
#     Site_EPA_ID        City  County_FIPS                  County    State  \
# 0  ALN000410750  Birmingham         1073               Jefferson  Alabama
# 1  AL7210020742  Huntsville         1089                 Madison  Alabama
# 2  AL0001058056  Montgomery         1101              Montgomery  Alabama
# 3  ALD007454085  Montgomery         1101              Montgomery  Alabama
# 4  AK6214522157   Anchorage         2020  Anchorage Municipality   Alaska
#
#   StateAbbr   Longitude   Latitude
# 0        AL  -86.799671  33.557464
# 1        AL  -86.673055  34.646944
# 2        AL  -86.306000  32.382000
# 3        AL  -86.379100  32.376100
# 4        AK -149.700000  61.258333

# %%
sfdf = sfdf[['Site_EPA_ID', 'County_FIPS', 'Longitude', 'Latitude']]

# %%
sfdf.describe()
# Out:
#         County_FIPS   Longitude    Latitude
# count    238.000000  238.000000  238.000000
# mean   26248.495798  -97.652360   37.193208
# std    17754.618059   16.913497    5.692965
# min     1073.000000 -149.700000   25.815200
# 25%    12003.000000 -117.347250   32.955280
# 50%    19622.000000  -91.183277   37.391500
# 75%    45842.500000  -83.231844   41.239169
# max    56021.000000  -74.085561   61.258333

# %% [markdown]
# Joining data on County_FIPS

# %%
outerdf = sfdf.merge(citydf, how = 'outer', left_on="County_FIPS",  right_on = 'CountyFIPS')
outerdf = outerdf.dropna(subset = ['Site_EPA_ID'])
outerdf = outerdf.dropna(subset = ['city_state'])
outerdf.describe()
# Out:
#         County_FIPS  Longitude_x   Latitude_x     PlaceFIPS     TractFIPS  \
# count   2472.000000  2472.000000  2472.000000  2.472000e+03  2.472000e+03
# mean   25271.216828  -103.131363    34.620644  2.562018e+06  2.527149e+10
# std    19655.830676    15.228380     5.256095  1.956955e+06  1.965580e+10
# min     1073.000000  -149.700000    25.815200  1.070000e+05  1.073003e+09
# 25%     6071.000000  -118.167434    29.798331  6.599620e+05  6.071002e+09
# 50%    17031.000000   -97.401494    34.098061  1.714000e+06  1.703180e+10
# 75%    48201.000000   -90.040165    37.401200  4.835000e+06  4.820125e+10
# max    56021.000000   -74.085561    61.258333  5.613900e+06  5.602100e+10
#
#          CountyFIPS   Latitude_y  Longitude_y
# count   2472.000000  2472.000000  2472.000000
# mean   25271.216828    34.636244  -103.129501
# std    19655.830676     5.225091    15.198392
# min     1073.000000    25.767793  -149.891260
# 25%     6071.000000    29.973337  -118.090898
# 50%    17031.000000    33.981344   -97.056833
# 75%    48201.000000    37.369669   -90.009454
# max    56021.000000    61.217709   -74.066961

# %%
outerdf.head()
# Out:
#     Site_EPA_ID  County_FIPS  Longitude_x  Latitude_x StateAbbr   PlaceName  \
# 0  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 1  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 2  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 3  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 4  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
#
#    PlaceFIPS     TractFIPS        Place_TractID  CountyFIPS  Latitude_y  \
# 0   107000.0  1.073003e+09  0107000-01073003200      1073.0   33.509402
# 1   107000.0  1.073003e+09  0107000-01073003300      1073.0   33.517126
# 2   107000.0  1.073010e+09  0107000-01073010500      1073.0   33.436379
# 3   107000.0  1.073011e+09  0107000-01073010701      1073.0   33.473886
# 4   107000.0  1.073011e+09  0107000-01073010801      1073.0   33.514098
#
#    Longitude_y     city_state
# 0   -86.885908  Birmingham_AL
# 1   -86.891382  Birmingham_AL
# 2   -86.912892  Birmingham_AL
# 3   -86.814649  Birmingham_AL
# 4   -86.746697  Birmingham_AL

# %%
outerdf['SFcoor'] = list(zip(outerdf.Latitude_x, outerdf.Longitude_x))
outerdf['Tractcoor'] = list(zip(outerdf.Latitude_y, outerdf.Longitude_y))

# %%
# Function from https://github.com/ashutoshb418/Foodies-Visualization/blob/master/Foodies_Chain.ipynb
def distance_from(loc1,loc2): 
    dist=hs.haversine(loc1,loc2)
    return round(dist,5)

# %%
# Calculate distances
outerdf['dist']=outerdf.apply(lambda row: distance_from(row.SFcoor,row.Tractcoor), axis = 1)

# %%
# Determine the min for each Superfund site
outerdf['mindist'] = outerdf.groupby(outerdf.Site_EPA_ID).dist.transform('min')
outerdf.head()
# Out:
#     Site_EPA_ID  County_FIPS  Longitude_x  Latitude_x StateAbbr   PlaceName  \
# 0  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 1  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 2  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 3  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 4  ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
#
#    PlaceFIPS     TractFIPS        Place_TractID  CountyFIPS  Latitude_y  \
# 0   107000.0  1.073003e+09  0107000-01073003200      1073.0   33.509402
# 1   107000.0  1.073003e+09  0107000-01073003300      1073.0   33.517126
# 2   107000.0  1.073010e+09  0107000-01073010500      1073.0   33.436379
# 3   107000.0  1.073011e+09  0107000-01073010701      1073.0   33.473886
# 4   107000.0  1.073011e+09  0107000-01073010801      1073.0   33.514098
#
#    Longitude_y     city_state                   SFcoor  \
# 0   -86.885908  Birmingham_AL  (33.557464, -86.799671)
# 1   -86.891382  Birmingham_AL  (33.557464, -86.799671)
# 2   -86.912892  Birmingham_AL  (33.557464, -86.799671)
# 3   -86.814649  Birmingham_AL  (33.557464, -86.799671)
# 4   -86.746697  Birmingham_AL  (33.557464, -86.799671)
#
#                          Tractcoor      dist  mindist
# 0  (33.5094018502, -86.8859081961)   9.61520  6.88186
# 1  (33.5171261108, -86.8913819749)   9.61098  6.88186
# 2  (33.4363786806, -86.9128923072)  17.07350  6.88186
# 3   (33.473886155, -86.8146487762)   9.39661  6.88186
# 4   (33.514097853, -86.7466971362)   6.88186  6.88186

# %%
# Limit to the closest site
df = outerdf[outerdf.dist == outerdf.mindist]

# %%
df['SFCount'] = df.groupby(df.TractFIPS).dist.transform('count')
df.head()
# Out:
# C:\Users\carry\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      Site_EPA_ID  County_FIPS  Longitude_x  Latitude_x StateAbbr   PlaceName  \
# 4   ALN000410750       1073.0   -86.799671   33.557464        AL  Birmingham
# 29  AL7210020742       1089.0   -86.673055   34.646944        AL  Huntsville
# 31  AL0001058056       1101.0   -86.306000   32.382000        AL  Montgomery
# 42  ALD007454085       1101.0   -86.379100   32.376100        AL  Montgomery
# 43  AK6214522157       2020.0  -149.700000   61.258333        AK   Anchorage
#
#     PlaceFIPS     TractFIPS        Place_TractID  CountyFIPS  Latitude_y  \
# 4    107000.0  1.073011e+09  0107000-01073010801      1073.0   33.514098
# 29   137000.0  1.089011e+09  0137000-01089011022      1089.0   34.699003
# 31   151000.0  1.101005e+09  0151000-01101005301      1101.0   32.406769
# 42   151000.0  1.101006e+09  0151000-01101005901      1101.0   32.293589
# 43   203000.0  2.020001e+09  0203000-02020001100      2020.0   61.217709
#
#     Longitude_y     city_state                   SFcoor  \
# 4    -86.746697  Birmingham_AL  (33.557464, -86.799671)
# 29   -86.710815  Huntsville_AL  (34.646944, -86.673055)
# 31   -86.246702  Montgomery_AL        (32.382, -86.306)
# 42   -86.353215  Montgomery_AL      (32.3761, -86.3791)
# 43  -149.891260   Anchorage_AK      (61.258333, -149.7)
#
#                           Tractcoor      dist   mindist  SFCount
# 4    (33.514097853, -86.7466971362)   6.88186   6.88186        1
# 29  (34.6990029313, -86.7108145743)   6.74037   6.74037        1
# 31   (32.4067693075, -86.246702078)   6.21154   6.21154        1
# 42  (32.2935892389, -86.3532149081)   9.49164   9.49164        1
# 43  (61.2177091891, -149.891260329)  11.18583  11.18583        1

# %%
newdf = df[['Place_TractID', 'SFCount']]
newdf.describe()
# Out:
#           SFCount
# count  235.000000
# mean     2.276596
# std      1.812847
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      3.000000
# max      8.000000

# %%
SF = newdf.merge(citydf, on = 'Place_TractID', how = 'left')
SF.head()
# Out:
#          Place_TractID  SFCount StateAbbr   PlaceName  PlaceFIPS   TractFIPS  \
# 0  0107000-01073010801        1        AL  Birmingham     107000  1073010801
# 1  0137000-01089011022        1        AL  Huntsville     137000  1089011022
# 2  0151000-01101005301        1        AL  Montgomery     151000  1101005301
# 3  0151000-01101005901        1        AL  Montgomery     151000  1101005901
# 4  0203000-02020001100        1        AK   Anchorage     203000  2020001100
#
#    CountyFIPS   Latitude   Longitude     city_state
# 0        1073  33.514098  -86.746697  Birmingham_AL
# 1        1089  34.699003  -86.710815  Huntsville_AL
# 2        1101  32.406769  -86.246702  Montgomery_AL
# 3        1101  32.293589  -86.353215  Montgomery_AL
# 4        2020  61.217709 -149.891260   Anchorage_AK

# %%
finalSF = SF[['StateAbbr','PlaceName','city_state','PlaceFIPS','TractFIPS','CountyFIPS','Place_TractID','SFCount']]
finalSF.head()
# Out:
#   StateAbbr   PlaceName     city_state  PlaceFIPS   TractFIPS  CountyFIPS  \
# 0        AL  Birmingham  Birmingham_AL     107000  1073010801        1073
# 1        AL  Huntsville  Huntsville_AL     137000  1089011022        1089
# 2        AL  Montgomery  Montgomery_AL     151000  1101005301        1101
# 3        AL  Montgomery  Montgomery_AL     151000  1101005901        1101
# 4        AK   Anchorage   Anchorage_AK     203000  2020001100        2020
#
#          Place_TractID  SFCount
# 0  0107000-01073010801        1
# 1  0137000-01089011022        1
# 2  0151000-01101005301        1
# 3  0151000-01101005901        1
# 4  0203000-02020001100        1

# %%
# Saving Cleaned data into csv
output_file_path = "../ProcessedData/FinalSuperFund.csv"
finalSF.to_csv(output_file_path, index=False)
