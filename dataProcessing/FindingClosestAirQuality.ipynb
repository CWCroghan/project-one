# %% [markdown]
# # Purpose of this program
# 1. Calculate the distances between Sources and Outcomes
# 2. Determine to closest Source to Outcome
# 3. Assign that Source to the closest Outcome.
#
# We will be using Haversine formula to calculate the distance between the Sources and Outcomes.
#
# We will be limiting the search for the closest to those Sources that are in the same City as the Outcomes.
#
# This program will be used on both the Superfund, Cumlivative Risk, and Air Quality data.

# %%
import pandas as pd
# Import the Numpy dependency
import numpy as np
# Import the Haversine formula package.  Calculates distances using lat & log
import haversine as hs
from haversine import Unit

# %% [markdown]
# Bring in Outcome data (500 City) only keeping locational information for now

# %%
# Bringing in 500 city data 
city_file_path = "../ProcessedData/500_City_cleaned.csv"
citydf = pd.read_csv(city_file_path)
citydf.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073003200  0107000-01073003200
# 1        AL  Birmingham     107000  1073003300  0107000-01073003300
# 2        AL  Birmingham     107000  1073010500  0107000-01073010500
# 3        AL  Birmingham     107000  1073010701  0107000-01073010701
# 4        AL  Birmingham     107000  1073010801  0107000-01073010801
#
#    Population2010  Insurance  HighBloodPressure  Cancer  Asthma  HeartDisease  \
# 0           931.0       26.8               57.0     6.0    14.4          11.1
# 1           947.0       21.4               55.2     6.8    12.9           9.7
# 2           114.0       23.9               60.5     7.1    13.6          11.1
# 3            74.0       19.8               24.9     2.7    11.2           2.4
# 4           168.0        7.3               33.0     7.4     8.9           4.5
#
#    AnnualCheckUps  Smokes  MentalHealthIssues   Latitude  Longitude  newFIPS  \
# 0            78.2    29.6                22.0  33.509402 -86.885908     1073
# 1            80.1    22.6                16.7  33.517126 -86.891382     1073
# 2            80.7    26.5                18.6  33.436379 -86.912892     1073
# 3            66.2    18.1                16.1  33.473886 -86.814649     1073
# 4            73.7     8.5                 8.8  33.514098 -86.746697     1073
#
#    CountyFIPS
# 0        1073
# 1        1073
# 2        1073
# 3        1073
# 4        1073

# %%
citydf = citydf[['StateAbbr','PlaceName','PlaceFIPS','TractFIPS','Place_TractID',
                 'CountyFIPS','Latitude','Longitude']]

# %%
citydf['city_state'] = citydf.PlaceName + "_" +  citydf.StateAbbr

# %%
citydf.groupby(citydf.Place_TractID).describe()
# Out:
#                     PlaceFIPS                                                  \
#                         count       mean std        min        25%        50%
# Place_TractID
# 0107000-01073003200       1.0   107000.0 NaN   107000.0   107000.0   107000.0
# 0107000-01073003300       1.0   107000.0 NaN   107000.0   107000.0   107000.0
# 0107000-01073010500       1.0   107000.0 NaN   107000.0   107000.0   107000.0
# 0107000-01073010701       1.0   107000.0 NaN   107000.0   107000.0   107000.0
# 0107000-01073010801       1.0   107000.0 NaN   107000.0   107000.0   107000.0
# ...                       ...        ...  ..        ...        ...        ...
# 5566000-55101001505       1.0  5566000.0 NaN  5566000.0  5566000.0  5566000.0
# 5584250-55133202902       1.0  5584250.0 NaN  5584250.0  5584250.0  5584250.0
# 5584250-55133203804       1.0  5584250.0 NaN  5584250.0  5584250.0  5584250.0
# 5613900-56021000402       1.0  5613900.0 NaN  5613900.0  5613900.0  5613900.0
# 5613900-56021002000       1.0  5613900.0 NaN  5613900.0  5613900.0  5613900.0
#
#                                           TractFIPS                ...  \
#                            75%        max     count          mean  ...
# Place_TractID                                                      ...
# 0107000-01073003200   107000.0   107000.0       1.0  1.073003e+09  ...
# 0107000-01073003300   107000.0   107000.0       1.0  1.073003e+09  ...
# 0107000-01073010500   107000.0   107000.0       1.0  1.073010e+09  ...
# 0107000-01073010701   107000.0   107000.0       1.0  1.073011e+09  ...
# 0107000-01073010801   107000.0   107000.0       1.0  1.073011e+09  ...
# ...                        ...        ...       ...           ...  ...
# 5566000-55101001505  5566000.0  5566000.0       1.0  5.510100e+10  ...
# 5584250-55133202902  5584250.0  5584250.0       1.0  5.513320e+10  ...
# 5584250-55133203804  5584250.0  5584250.0       1.0  5.513320e+10  ...
# 5613900-56021000402  5613900.0  5613900.0       1.0  5.602100e+10  ...
# 5613900-56021002000  5613900.0  5613900.0       1.0  5.602100e+10  ...
#
#                       Latitude            Longitude                  \
#                            75%        max     count        mean std
# Place_TractID
# 0107000-01073003200  33.509402  33.509402       1.0  -86.885908 NaN
# 0107000-01073003300  33.517126  33.517126       1.0  -86.891382 NaN
# 0107000-01073010500  33.436379  33.436379       1.0  -86.912892 NaN
# 0107000-01073010701  33.473886  33.473886       1.0  -86.814649 NaN
# 0107000-01073010801  33.514098  33.514098       1.0  -86.746697 NaN
# ...                        ...        ...       ...         ...  ..
# 5566000-55101001505  42.771772  42.771772       1.0  -87.785185 NaN
# 5584250-55133202902  43.022614  43.022614       1.0  -88.193942 NaN
# 5584250-55133203804  43.016192  43.016192       1.0  -88.295400 NaN
# 5613900-56021000402  41.120901  41.120901       1.0 -104.773244 NaN
# 5613900-56021002000  41.133617  41.133617       1.0 -104.719054 NaN
#
#                                                                      \
#                             min         25%         50%         75%
# Place_TractID
# 0107000-01073003200  -86.885908  -86.885908  -86.885908  -86.885908
# 0107000-01073003300  -86.891382  -86.891382  -86.891382  -86.891382
# 0107000-01073010500  -86.912892  -86.912892  -86.912892  -86.912892
# 0107000-01073010701  -86.814649  -86.814649  -86.814649  -86.814649
# 0107000-01073010801  -86.746697  -86.746697  -86.746697  -86.746697
# ...                         ...         ...         ...         ...
# 5566000-55101001505  -87.785185  -87.785185  -87.785185  -87.785185
# 5584250-55133202902  -88.193942  -88.193942  -88.193942  -88.193942
# 5584250-55133203804  -88.295400  -88.295400  -88.295400  -88.295400
# 5613900-56021000402 -104.773244 -104.773244 -104.773244 -104.773244
# 5613900-56021002000 -104.719054 -104.719054 -104.719054 -104.719054
#
#
#                             max
# Place_TractID
# 0107000-01073003200  -86.885908
# 0107000-01073003300  -86.891382
# 0107000-01073010500  -86.912892
# 0107000-01073010701  -86.814649
# 0107000-01073010801  -86.746697
# ...                         ...
# 5566000-55101001505  -87.785185
# 5584250-55133202902  -88.193942
# 5584250-55133203804  -88.295400
# 5613900-56021000402 -104.773244
# 5613900-56021002000 -104.719054
#
# [1378 rows x 40 columns]

# %% [markdown]
# Reading in Source and limiting it to select cities

# %%
# Reading in Cleaned AirQuality data
input_file_path = "../ProcessedData/AirQuality_cleaned.csv"
aqdf = pd.read_csv(input_file_path)
aqdf.head()
# Out:
#    SiteId   Latitude  Longitude Sample Duration  PM2.5_Exceptional  \
# 0      11  33.553056 -86.815000   24-HR BLK AVG                  0
# 1      15  33.499722 -86.924167         24 HOUR                  0
# 2      17  33.521427 -86.844112         24 HOUR                  0
# 3      25  34.685470 -86.588160         24 HOUR                  0
# 4      29  32.412811 -86.263394         24 HOUR                  0
#
#    PM2.5_ExceedCount  PM2.5_Max    State      County        City  index  \
# 0                0.0       26.6  Alabama   Jefferson  Birmingham     69
# 1                0.0       22.0  Alabama   Jefferson  Birmingham    306
# 2                0.0       23.1  Alabama   Jefferson  Birmingham    411
# 3                0.0       18.5  Alabama     Madison  Huntsville    500
# 4                0.0       20.8  Alabama  Montgomery  Montgomery    564
#
#    Ozone_Exceptional  Ozone_ExceedCount  Ozone_Max StateAbbr     city_state
# 0                0.0                1.0      0.078        AL  Birmingham_AL
# 1                NaN                NaN        NaN        AL  Birmingham_AL
# 2                NaN                NaN        NaN        AL  Birmingham_AL
# 3                0.0                0.0      0.070        AL  Huntsville_AL
# 4                0.0                0.0      0.060        AL  Montgomery_AL

# %%
aqdf2 = aqdf[['StateAbbr','SiteId', 'Longitude', 'Latitude']]

# %%
aqdf2.describe()
# Out:
#             SiteId   Longitude    Latitude
# count   324.000000  324.000000  324.000000
# mean   1188.222222  -97.489493   37.482421
# std     776.866892   16.597165    5.278893
# min      11.000000 -157.871171   21.303382
# 25%     481.000000 -112.075260   33.517029
# 50%    1165.500000  -93.719149   37.875397
# 75%    1846.000000  -83.912782   41.116006
# max    2595.000000  -71.054300   61.326700

# %% [markdown]
# Joining data on County_FIPS

# %%
outerdf = aqdf2.merge(citydf, how = 'outer', left_on="StateAbbr",  right_on = 'StateAbbr')
outerdf = outerdf.dropna(subset = ['StateAbbr'])
outerdf = outerdf.dropna(subset = ['city_state'])
outerdf.describe()
# Out:
#              SiteId   Longitude_x    Latitude_x     PlaceFIPS     TractFIPS  \
# count  23560.000000  23560.000000  23560.000000  2.356600e+04  2.356600e+04
# mean     955.969652   -105.275691     35.141522  2.074561e+06  2.042622e+10
# std      822.157189     15.701804      4.373967  1.815838e+06  1.823915e+10
# min       11.000000   -157.871171     21.303382  1.500300e+04  1.073003e+09
# 25%      304.000000   -119.691218     32.774262  6.440000e+05  6.059076e+09
# 50%      441.000000   -111.872222     34.669739  6.842000e+05  6.099004e+09
# 75%     1817.000000    -92.042908     37.936013  3.921000e+06  3.915171e+10
# max     2595.000000    -71.054300     61.326700  5.613900e+06  5.602100e+10
#
#          CountyFIPS    Latitude_y   Longitude_y
# count  23566.000000  23566.000000  23566.000000
# mean   20426.033523     34.766271   -104.640982
# std    18239.166553      4.202529     15.343090
# min     1073.000000     21.281244   -158.112465
# 25%     6059.000000     32.776174   -117.984959
# 50%     6099.000000     33.988256   -111.641931
# 75%    39151.000000     37.704110    -91.620675
# max    56021.000000     61.217709    -70.965134

# %%
outerdf.head()
# Out:
#   StateAbbr  SiteId  Longitude_x  Latitude_x   PlaceName  PlaceFIPS  \
# 0        AL    11.0      -86.815   33.553056  Birmingham     107000
# 1        AL    11.0      -86.815   33.553056  Birmingham     107000
# 2        AL    11.0      -86.815   33.553056  Birmingham     107000
# 3        AL    11.0      -86.815   33.553056  Birmingham     107000
# 4        AL    11.0      -86.815   33.553056  Birmingham     107000
#
#     TractFIPS        Place_TractID  CountyFIPS  Latitude_y  Longitude_y  \
# 0  1073003200  0107000-01073003200        1073   33.509402   -86.885908
# 1  1073003300  0107000-01073003300        1073   33.517126   -86.891382
# 2  1073010500  0107000-01073010500        1073   33.436379   -86.912892
# 3  1073010701  0107000-01073010701        1073   33.473886   -86.814649
# 4  1073010801  0107000-01073010801        1073   33.514098   -86.746697
#
#       city_state
# 0  Birmingham_AL
# 1  Birmingham_AL
# 2  Birmingham_AL
# 3  Birmingham_AL
# 4  Birmingham_AL

# %%
outerdf['Sourcecoor'] = list(zip(outerdf.Latitude_x, outerdf.Longitude_x))
outerdf['Tractcoor'] = list(zip(outerdf.Latitude_y, outerdf.Longitude_y))

# %%
# Function from https://github.com/ashutoshb418/Foodies-Visualization/blob/master/Foodies_Chain.ipynb
def distance_from(loc1,loc2): 
    dist=hs.haversine(loc1,loc2)
    return round(dist,5)

# %%
# Calculate distances
outerdf['dist']=outerdf.apply(lambda row: distance_from(row.Sourcecoor,row.Tractcoor), axis = 1)

# %%
# Determine the min for each Air Quality site
outerdf['mindist'] = outerdf.groupby(outerdf.Place_TractID).dist.transform('min')
outerdf.head()
# Out:
#   StateAbbr  SiteId  Longitude_x  Latitude_x   PlaceName  PlaceFIPS  \
# 0        AL    11.0      -86.815   33.553056  Birmingham     107000
# 1        AL    11.0      -86.815   33.553056  Birmingham     107000
# 2        AL    11.0      -86.815   33.553056  Birmingham     107000
# 3        AL    11.0      -86.815   33.553056  Birmingham     107000
# 4        AL    11.0      -86.815   33.553056  Birmingham     107000
#
#     TractFIPS        Place_TractID  CountyFIPS  Latitude_y  Longitude_y  \
# 0  1073003200  0107000-01073003200        1073   33.509402   -86.885908
# 1  1073003300  0107000-01073003300        1073   33.517126   -86.891382
# 2  1073010500  0107000-01073010500        1073   33.436379   -86.912892
# 3  1073010701  0107000-01073010701        1073   33.473886   -86.814649
# 4  1073010801  0107000-01073010801        1073   33.514098   -86.746697
#
#       city_state            Sourcecoor                        Tractcoor  \
# 0  Birmingham_AL  (33.553056, -86.815)  (33.5094018502, -86.8859081961)
# 1  Birmingham_AL  (33.553056, -86.815)  (33.5171261108, -86.8913819749)
# 2  Birmingham_AL  (33.553056, -86.815)  (33.4363786806, -86.9128923072)
# 3  Birmingham_AL  (33.553056, -86.815)   (33.473886155, -86.8146487762)
# 4  Birmingham_AL  (33.553056, -86.815)   (33.514097853, -86.7466971362)
#
#        dist  mindist
# 0   8.17071  3.70702
# 1   8.12909  3.60344
# 2  15.83428  7.12068
# 3   8.80336  5.95055
# 4   7.67109  7.67109

# %%
# Limit to the closest site
df = outerdf[outerdf.dist == outerdf.mindist]

# %%
df = df.drop(['Sourcecoor','Longitude_x','Latitude_x'], axis=1)
# Find duplicates entries
print(f"Duplicate entries: {df.duplicated().sum()}")
df = df.drop_duplicates()
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 88
# Duplicate entries: 0

# %%
df2 = df[['Place_TractID','SiteId']]
df2.describe()
# Out:
#             SiteId
# count  1372.000000
# mean   1202.796647
# std     788.360509
# min      11.000000
# 25%     417.000000
# 50%    1166.000000
# 75%    1943.000000
# max    2595.000000

# %%
# Find duplicates entries
print(f"Duplicate entries: {df2.duplicated().sum()}")
df2 = df2.drop_duplicates()
print(f"Duplicate entries: {df2.duplicated().sum()}")
# Out:
# Duplicate entries: 0
# Duplicate entries: 0

# %%
city = df2.merge(citydf, on = 'Place_TractID', how = 'left')
city.head()
# Out:
#          Place_TractID  SiteId StateAbbr   PlaceName  PlaceFIPS   TractFIPS  \
# 0  0107000-01073010801    11.0        AL  Birmingham     107000  1073010801
# 1  0107000-01073010803    11.0        AL  Birmingham     107000  1073010803
# 2  0107000-01073010805    11.0        AL  Birmingham     107000  1073010805
# 3  0107000-01073011207    11.0        AL  Birmingham     107000  1073011207
# 4  0107000-01073011803    11.0        AL  Birmingham     107000  1073011803
#
#    CountyFIPS   Latitude  Longitude     city_state
# 0        1073  33.514098 -86.746697  Birmingham_AL
# 1        1073  33.522909 -86.710262  Birmingham_AL
# 2        1073  33.495279 -86.698718  Birmingham_AL
# 3        1073  33.671885 -86.677251  Birmingham_AL
# 4        1073  33.625258 -86.699861  Birmingham_AL

# %%
AQ = city[['StateAbbr','PlaceName','city_state','PlaceFIPS','TractFIPS','CountyFIPS','Place_TractID','SiteId']].merge(aqdf, on='SiteId', how = 'left')
AQ.columns
# Out:
# Index(['StateAbbr_x', 'PlaceName', 'city_state_x', 'PlaceFIPS', 'TractFIPS',
#        'CountyFIPS', 'Place_TractID', 'SiteId', 'Latitude', 'Longitude',
#        'Sample Duration', 'PM2.5_Exceptional', 'PM2.5_ExceedCount',
#        'PM2.5_Max', 'State', 'County', 'City', 'index', 'Ozone_Exceptional',
#        'Ozone_ExceedCount', 'Ozone_Max', 'StateAbbr_y', 'city_state_y'],
#       dtype='object')

# %%
print(f"Duplicate entries: {AQ.duplicated().sum()}")
finalAQ = AQ.drop_duplicates()
# Out:
# Duplicate entries: 48

# %%
# Drop repeat columns
newdf = finalAQ.drop(['StateAbbr_y', 'city_state_y'], axis=1)

# Rename
df = newdf.rename(columns={'StateAbbr_x': 'StateAbbr',
    'city_state_x': 'city_state'})

# reorder

finaldf = df[['StateAbbr','PlaceName','city_state','PlaceFIPS','TractFIPS',
              'CountyFIPS','Place_TractID','SiteId', 'PM2.5_Exceptional', 
              'PM2.5_ExceedCount', 'PM2.5_Max','Ozone_Exceptional', 
              'Ozone_ExceedCount', 'Ozone_Max']]

finaldf.columns
# Out:
# Index(['StateAbbr', 'PlaceName', 'city_state', 'PlaceFIPS', 'TractFIPS',
#        'CountyFIPS', 'Place_TractID', 'SiteId', 'PM2.5_Exceptional',
#        'PM2.5_ExceedCount', 'PM2.5_Max', 'Ozone_Exceptional',
#        'Ozone_ExceedCount', 'Ozone_Max'],
#       dtype='object')

# %%
finaldf = finaldf.groupby(finaldf.Place_TractID).last()
finaldf = finaldf.reset_index()
finaldf.head()
# Out:
#          Place_TractID StateAbbr   PlaceName     city_state  PlaceFIPS  \
# 0  0107000-01073003200        AL  Birmingham  Birmingham_AL     107000
# 1  0107000-01073003300        AL  Birmingham  Birmingham_AL     107000
# 2  0107000-01073010500        AL  Birmingham  Birmingham_AL     107000
# 3  0107000-01073010701        AL  Birmingham  Birmingham_AL     107000
# 4  0107000-01073010801        AL  Birmingham  Birmingham_AL     107000
#
#     TractFIPS  CountyFIPS  SiteId  PM2.5_Exceptional  PM2.5_ExceedCount  \
# 0  1073003200        1073    15.0                  0                0.0
# 1  1073003300        1073    15.0                  0                0.0
# 2  1073010500        1073    15.0                  0                0.0
# 3  1073010701        1073    17.0                  0                0.0
# 4  1073010801        1073    11.0                  0                0.0
#
#    PM2.5_Max  Ozone_Exceptional  Ozone_ExceedCount  Ozone_Max
# 0       22.0                NaN                NaN        NaN
# 1       22.0                NaN                NaN        NaN
# 2       22.0                NaN                NaN        NaN
# 3       23.1                NaN                NaN        NaN
# 4       26.6                0.0                1.0      0.078

# %%
# Saving Cleaned data into csv
output_file_path = "../ProcessedData/FinalAirQuality.csv"
finaldf.to_csv(output_file_path, index=False)

# %% [markdown]
# end of code

# %%
# check for multiple tracks
Place_TractIDdf = finaldf['Place_TractID']
print(f"Duplicate entries: {Place_TractIDdf.duplicated().sum()}")
# Out:
# Duplicate entries: 0
